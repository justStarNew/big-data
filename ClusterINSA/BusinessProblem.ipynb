# %% [markdown]
# # [Introduction to Deep Learning with Keras](https://heartbeat.fritz.ai/introduction-to-deep-learning-with-keras-c7c3d14e1527)
# Training an artificial neural network involves the following steps:
#
# 1. Weights are randomly initialized to numbers that are near zero but not zero.
# 2. Feed the observations of your dataset to the input layer.
# 3. Forward propagation (from left to right): neurons are activated and the predicted values are obtained.
# 4. Compare predicted results to actual values and measure the error.
# 5. Backward propagation (from right to left): weights are adjusted.
# 6. Repeat steps 1–5
# 7. One epoch is achieved when the whole training set has gone through the neural network.

# %% [markdown]
# ## Business problem data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/insurance_claims.csv")

df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# 5                   256   39         104594       2006-10-12           OH
# 6                   137   34         413978       2000-06-04           IN
# 7                   165   37         429027       1990-02-03           IL
# 8                    27   33         485665       1997-02-05           IL
# 9                   212   42         636550       2011-07-25           IL
# 10                  235   42         543610       2002-05-26           OH
# 11                  447   61         214618       1999-05-29           OH
# 12                   60   23         842643       1997-11-20           OH
# 13                  121   34         626808       2012-10-26           OH
# 14                  180   38         644081       1998-12-28           OH
# 15                  473   58         892874       1992-10-19           IN
# 16                   70   26         558938       2005-06-08           OH
# 17                  140   31         275265       2004-11-15           IN
# 18                  160   37         921202       2014-12-28           OH
# 19                  196   39         143972       1992-08-02           IN
# 20                  460   62         183430       2002-06-25           IN
# 21                  217   41         431876       2005-11-27           IL
# 22                  370   55         285496       1994-05-27           IL
# 23                  413   55         115399       1991-02-08           IN
# 24                  237   40         736882       1996-02-02           IN
# 25                    8   35         699044       2013-12-05           OH
# 26                  257   43         863236       1990-09-20           IN
# 27                  202   34         608513       2002-07-18           IN
# 28                  224   40         914088       1990-02-08           OH
# 29                  241   45         596785       2014-03-04           IL
# ..                  ...  ...            ...              ...          ...
# 970                 213   35         844129       1990-09-20           OH
# 971                  79   25         732169       2000-11-05           OH
# 972                 232   44         221854       1994-10-03           OH
# 973                 230   37         776950       2005-04-11           IL
# 974                 234   41         291006       1990-05-16           IN
# 975                 240   40         845751       2004-09-11           IN
# 976                 143   33         889764       1993-11-30           OH
# 977                 266   42         929306       2003-03-06           IN
# 978                  89   32         515457       1996-12-18           IN
# 979                 229   37         556270       1995-02-21           IN
# 980                 245   40         908935       2009-12-11           IL
# 981                  50   44         525862       2000-10-18           OH
# 982                 230   43         490514       2007-02-09           IN
# 983                  17   39         774895       2006-10-28           IL
# 984                 163   36         974522       2000-01-27           IN
# 985                  29   32         669809       2002-04-05           OH
# 986                 232   42         182953       2013-04-30           IN
# 987                 235   39         836349       2013-05-01           IL
# 988                 295   46         591269       1999-01-09           IN
# 989                  22   21         550127       2007-07-04           IN
# 990                 286   43         663190       1994-02-05           IL
# 991                 257   44         109392       2006-07-12           OH
# 992                  94   26         215278       2007-10-24           IN
# 993                 124   28         674570       2001-12-08           OH
# 994                 141   30         681486       2007-03-24           IN
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# 5      250/500               1000                1351.10               0
# 6      250/500               1000                1333.35               0
# 7      100/300               1000                1137.03               0
# 8      100/300                500                1442.99               0
# 9      100/300                500                1315.68               0
# 10     100/300                500                1253.12         4000000
# 11     100/300               2000                1137.16               0
# 12    500/1000                500                1215.36         3000000
# 13     100/300               1000                 936.61               0
# 14     250/500               2000                1301.13               0
# 15     100/300               2000                1131.40               0
# 16    500/1000               1000                1199.44         5000000
# 17    500/1000                500                 708.64         6000000
# 18    500/1000                500                1374.22               0
# 19    500/1000               2000                1475.73               0
# 20     250/500               1000                1187.96         4000000
# 21    500/1000               2000                 875.15               0
# 22     100/300               2000                 972.18               0
# 23     100/300               2000                1268.79               0
# 24     100/300               1000                 883.31               0
# 25     100/300               2000                1266.92               0
# 26     100/300               2000                1322.10               0
# 27     100/300                500                 848.07         3000000
# 28     100/300               2000                1291.70               0
# 29    500/1000               2000                1104.50               0
# ..         ...                ...                    ...             ...
# 970    250/500                500                 871.46               0
# 971   500/1000                500                1863.04               0
# 972    250/500               2000                1181.64               0
# 973   500/1000               1000                1060.74               0
# 974    100/300                500                 951.56               0
# 975    100/300                500                1533.71         9000000
# 976   500/1000               1000                1200.09               0
# 977    100/300                500                1093.83         4000000
# 978    250/500               1000                 988.93               0
# 979   500/1000               1000                1331.94               0
# 980   500/1000               1000                1361.45               0
# 981    250/500               2000                1188.51               0
# 982   500/1000               2000                1101.83               0
# 983    250/500               1000                 840.95               0
# 984    250/500               1000                1503.21               0
# 985    100/300               1000                1722.50               0
# 986    100/300                500                 944.03               0
# 987   500/1000               2000                1453.61         4000000
# 988    100/300                500                1672.88               0
# 989    250/500               1000                1248.05               0
# 990    100/300                500                1564.43         3000000
# 991    100/300               1000                1280.88               0
# 992    100/300                500                 722.66               0
# 993    250/500               1000                1235.14               0
# 994   500/1000               1000                1347.04               0
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip      ...       witnesses police_report_available  \
# 0         466132      ...               2                     YES
# 1         468176      ...               0                       ?
# 2         430632      ...               3                      NO
# 3         608117      ...               2                      NO
# 4         610706      ...               1                      NO
# 5         478456      ...               2                      NO
# 6         441716      ...               0                       ?
# 7         603195      ...               2                     YES
# 8         601734      ...               1                     YES
# 9         600983      ...               1                       ?
# 10        462283      ...               2                       ?
# 11        615561      ...               2                     YES
# 12        432220      ...               0                      NO
# 13        464652      ...               1                      NO
# 14        476685      ...               2                     YES
# 15        458733      ...               0                      NO
# 16        619884      ...               2                     YES
# 17        470610      ...               2                     YES
# 18        472135      ...               0                      NO
# 19        477670      ...               0                      NO
# 20        618845      ...               0                       ?
# 21        442479      ...               2                       ?
# 22        443920      ...               0                     YES
# 23        453148      ...               2                       ?
# 24        434733      ...               3                      NO
# 25        613982      ...               3                     YES
# 26        436984      ...               3                     YES
# 27        607730      ...               1                       ?
# 28        609837      ...               0                     YES
# 29        432211      ...               2                      NO
# ..           ...      ...             ...                     ...
# 970       477938      ...               0                     YES
# 971       462698      ...               1                       ?
# 972       454552      ...               1                     YES
# 973       471585      ...               3                       ?
# 974       455426      ...               1                       ?
# 975       469856      ...               2                       ?
# 976       454191      ...               2                       ?
# 977       468454      ...               1                      NO
# 978       614187      ...               3                     YES
# 979       433974      ...               2                     YES
# 980       604833      ...               2                     YES
# 981       447469      ...               2                      NO
# 982       451529      ...               3                     YES
# 983       431202      ...               1                       ?
# 984       448190      ...               1                      NO
# 985       453713      ...               2                       ?
# 986       440153      ...               3                       ?
# 987       619570      ...               3                       ?
# 988       478947      ...               1                      NO
# 989       443550      ...               2                       ?
# 990       477644      ...               2                     YES
# 991       433981      ...               1                      NO
# 992       433696      ...               2                     YES
# 993       443567      ...               1                       ?
# 994       430665      ...               2                     YES
# 995       431289      ...               1                       ?
# 996       608177      ...               3                       ?
# 997       442797      ...               3                     YES
# 998       441714      ...               1                     YES
# 999       612260      ...               3                       ?
#
#     total_claim_amount injury_claim property_claim  vehicle_claim   auto_make  \
# 0                71610         6510          13020          52080        Saab
# 1                 5070          780            780           3510    Mercedes
# 2                34650         7700           3850          23100       Dodge
# 3                63400         6340           6340          50720   Chevrolet
# 4                 6500         1300            650           4550      Accura
# 5                64100         6410           6410          51280        Saab
# 6                78650        21450           7150          50050      Nissan
# 7                51590         9380           9380          32830        Audi
# 8                27700         2770           2770          22160      Toyota
# 9                42300         4700           4700          32900        Saab
# 10               87010         7910          15820          63280        Ford
# 11              114920        17680          17680          79560        Audi
# 12               56520         4710           9420          42390        Saab
# 13                7280         1120           1120           5040      Toyota
# 14               46200         4200           8400          33600       Dodge
# 15               63120        10520          10520          42080      Accura
# 16               52110         5790           5790          40530      Nissan
# 17               77880        14160           7080          56640      Suburu
# 18               72930         6630          13260          53040      Accura
# 19               60400         6040           6040          48320      Nissan
# 20               47160            0           5240          41920      Suburu
# 21               37840            0           4730          33110      Accura
# 22               71520        17880           5960          47680      Suburu
# 23               98160         8180          16360          73620       Dodge
# 24               77880         7080          14160          56640        Ford
# 25               71500        16500          11000          44000        Ford
# 26                9020         1640            820           6560      Toyota
# 27                5720         1040            520           4160      Suburu
# 28               69840         7760          15520          46560       Dodge
# 29               91650        14100          14100          63450      Accura
# ..                 ...          ...            ...            ...         ...
# 970              74140        13480           6740          53920        Ford
# 971              67800        13560           6780          47460    Mercedes
# 972              55400         5540          11080          38780        Jeep
# 973              49100         9820           4910          34370      Suburu
# 974              98280        15120           7560          75600   Chevrolet
# 975              66550         6050          12100          48400        Ford
# 976              70400        14080           7040          49280      Accura
# 977              53280         4440           8880          39960      Suburu
# 978              84590        15380          15380          53830       Dodge
# 979              54560         9920           9920          34720        Saab
# 980              82170         7470           7470          67230      Suburu
# 981              61100         6110          12220          42770       Dodge
# 982              51900         5190          10380          36330         BMW
# 983               3440          430            430           2580      Suburu
# 984              51390         5710          11420          34260      Toyota
# 985              76900         7690           7690          61520        Jeep
# 986              77000        15400           7700          53900      Toyota
# 987              60320         9280           9280          41760   Chevrolet
# 988              60700        12140           6070          42490       Honda
# 989              53280         5920              0          47360   Chevrolet
# 990              34290         3810           3810          26670        Jeep
# 991              46980            0           5220          41760      Accura
# 992              36700         3670           7340          25690      Nissan
# 993              60200         6020           6020          48160  Volkswagen
# 994               6480          540           1080           4860       Honda
# 995              87200        17440           8720          61040       Honda
# 996             108480        18080          18080          72320  Volkswagen
# 997              67500         7500           7500          52500      Suburu
# 998              46980         5220           5220          36540        Audi
# 999               5060          460            920           3680    Mercedes
#
#          auto_model auto_year fraud_reported
# 0               92x      2004              Y
# 1              E400      2007              Y
# 2               RAM      2007              N
# 3             Tahoe      2014              Y
# 4               RSX      2009              N
# 5                95      2003              Y
# 6        Pathfinder      2012              N
# 7                A5      2015              N
# 8             Camry      2012              N
# 9               92x      1996              N
# 10             F150      2002              N
# 11               A3      2006              N
# 12               95      2000              N
# 13       Highlander      2010              N
# 14             Neon      2003              Y
# 15              MDX      1999              Y
# 16           Maxima      2012              N
# 17           Legacy      2015              N
# 18               TL      2015              N
# 19       Pathfinder      2014              N
# 20          Impreza      2011              N
# 21              RSX      1996              N
# 22        Forrestor      2000              Y
# 23              RAM      2011              Y
# 24           Escape      2005              N
# 25           Escape      2006              Y
# 26            Camry      2005              N
# 27        Forrestor      2003              Y
# 28             Neon      2009              N
# 29               TL      2011              N
# ..              ...       ...            ...
# 970          Escape      2007              N
# 971            C300      1995              N
# 972  Grand Cherokee      2002              Y
# 973         Impreza      1996              Y
# 974           Tahoe      2007              Y
# 975          Escape      2008              N
# 976             RSX      2002              N
# 977         Impreza      2015              Y
# 978            Neon      1999              N
# 979              95      2004              N
# 980       Forrestor      1999              N
# 981            Neon      2008              N
# 982              M5      2011              Y
# 983          Legacy      2002              N
# 984         Corolla      2013              N
# 985        Wrangler      1995              N
# 986      Highlander      2015              Y
# 987           Tahoe      2012              Y
# 988           Civic      1997              N
# 989          Malibu      2015              N
# 990  Grand Cherokee      2013              N
# 991              TL      2002              N
# 992      Pathfinder      2010              N
# 993          Passat      2012              N
# 994           Civic      1996              N
# 995          Accord      2006              N
# 996          Passat      2015              N
# 997         Impreza      1996              N
# 998              A5      1998              N
# 999            E400      2007              N
#
# [1000 rows x 39 columns]

# %% [markdown]
# # convert the categorical columns to dummy variables.

# %%
feats = ["policy_state",
         "insured_sex",
         "insured_education_level",
         "insured_occupation",
         "insured_hobbies",
         "insured_relationship",
         "collision_type",
         "incident_severity",
         "authorities_contacted",
         "incident_state",
         "incident_city",
         "incident_location",
         "property_damage",
         "police_report_available",
         "auto_make",
         "auto_model",
         'fraud_reported',
         "incident_type"]

df_final = pd.get_dummies(df,columns=feats,drop_first=True)

df_final.shape
# Out:
# (1000, 1147)

# %% [markdown]
# # split the data into a training set and a test set.

# %%
from sklearn.model_selection import train_test_split

X = df_final.drop(["fraud_reported_Y",
                   "policy_csl",
                   "policy_bind_date",
                   "incident_date"],axis=1).values

y = df_final["fraud_reported_Y"].values

# %%
y.shape
# Out:
# (1000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## Scale the dataset

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (700, 1143)

# %% [markdown]
# ## Building the Artificial Neural Network

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential()

classifier.add(
     Dense(3, kernel_initializer = "uniform",
              activation = "relu", input_dim=5))

classifier.add(
     Dense(3, kernel_initializer = "uniform",
              activation = "relu"))
classifier.add(
     Dense(1, kernel_initializer = "uniform",
              activation = "sigmoid"))

classifier.compile(optimizer= "adam",
                  loss = "binary_crossentropy",
                  metrics = ["accuracy"])

classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)

y_pred = classifier.predict(X_test)

y_pred = (y_pred > 0.5)

y_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ef22daf4d54e> in <module>
#      20                   metrics = ["accuracy"])
#      21
# ---> 22 classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
#      23
#      24 y_pred = classifier.predict(X_test)
#
# /opt/miniconda3/envs/big-data/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# /opt/miniconda3/envs/big-data/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# /opt/miniconda3/envs/big-data/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected dense_13_input to have shape (5,) but got array with shape (1143,)

# %% [markdown]
# ## Checking the confusion matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-cc8b7f1d4658> in <module>
#       1 from sklearn.metrics import confusion_matrix
#       2
# ----> 3 cm = confusion_matrix(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
#new_pred = classifier.predict(sc.transform(np.array([[a,b,c,d]])))

from keras.wrappers.scikit_learn import KerasClassifier

from sklearn.model_selection import cross_val_score

def make_classifier():
    classifier = Sequential()
    classifier.add(Dense(3, kernel_initializer = "uniform", activation = "relu", input_dim=5))
    classifier.add(Dense(3, kernel_initializer = "uniform", activation = "relu"))
    classifier.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))
    classifier.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])
    return classifier

accuracies = cross_val_score(estimator = classifier,
                             X = X_train,
                             y = y_train,
                             cv = 10,
                             n_jobs = -1)

mean = accuracies.mean()
variance = accuracies.var()

from keras.layers import Dropout

classifier = Sequential()
classifier.add(Dense(3, kernel_initializer = "uniform", activation = "relu", input_dim=5))

# Notice the dropouts
classifier.add(Dropout(rate = 0.1))
classiifier.add(Dense(6, kernel_initializer = "uniform", activation = "relu"))
classifier.add(Dropout(rate = 0.1))

classifier.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))
classifier.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

from sklearn.model_selection import GridSearchCV

def make_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(6, kernel_initializer = "uniform", activation = "relu", input_dim=11))
    classifier.add(Dense(6, kernel_initializer = "uniform", activation = "relu"))
    classifier.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))
    classifier.compile(optimizer= optimizer,loss = "binary_crossentropy",metrics = ["accuracy"])
    return classifier

classifier = KerasClassifier(build_fn = make_classifier)

params = {
    "batch_size":[20,35],

    "nb_epoch":[150,500],

    "Optimizer":['adam','rmsprop']
}

grid_search = GridSearchCV(estimator=classifier,
                           param_grid=params,
                           scoring="accuracy",
                           cv=10)

grid_search = grid_search.fit(X_train,y_train)

best_param = grid_search.best_params_

best_accuracy = grid_search.best_score_
